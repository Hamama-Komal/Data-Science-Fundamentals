# %%
from matplotlib.image import imread

# %%
import matplotlib.pyplot as plt

# %%
img_data = imread('img.jpg')

# %%
img_data     # Gives the pixel value of image
# Out:
# array([[[  6,   6,   6],
#         [ 20,  20,  20],
#         [ 34,  34,  34],
#         ...,
#         [ 35,  35,  35],
#         [103, 103, 103],
#         [128, 128, 128]],
#
#        [[ 14,  14,  14],
#         [  8,   8,   8],
#         [ 19,  19,  19],
#         ...,
#         [ 29,  29,  29],
#         [ 86,  86,  86],
#         [107, 107, 107]],
#
#        [[ 48,  48,  48],
#         [ 11,  11,  11],
#         [  4,   4,   4],
#         ...,
#         [ 38,  38,  38],
#         [103, 103, 103],
#         [127, 127, 127]],
#
#        ...,
#
#        [[  3,   3,   3],
#         [  0,   0,   0],
#         [  5,   5,   5],
#         ...,
#         [ 66,  66,  66],
#         [ 64,  64,  64],
#         [ 56,  56,  56]],
#
#        [[  1,   1,   1],
#         [  0,   0,   0],
#         [  2,   2,   2],
#         ...,
#         [ 79,  79,  79],
#         [ 79,  79,  79],
#         [ 74,  74,  74]],
#
#        [[  3,   3,   3],
#         [  0,   0,   0],
#         [  2,   2,   2],
# ...

# %%
plt.figure()

# %%
plt.imshow(img_data)    # use to view the image

# %%
# Image is 3D: 1) x axis 2) y axis 3) RGB Colors

# %%
img_data.shape
# Out:
# (1460, 736, 3)
