# %%
import pandas as pd

# %%
data = pd.read_csv('test_dataset.csv')

# %%
data
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
# manipulating data

# %%
#  sample(frac) >>      Shuffle the row data & take the frac in %

# %%
data.sample(frac = 0.5)
# Out:
#       id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 967  968            636     1          2.6         1   7       1          55
# 192  193           1933     0          1.2         0  16       1          55
# 322  323           1337     1          2.4         1   0       0          48
# 456  457           1266     1          1.0         0   0       1           2
# 298  299           1430     1          2.0         1   0       1          16
# ..   ...            ...   ...          ...       ...  ..     ...         ...
# 202  203           1278     1          2.8         1   0       0          56
# 671  672           1544     0          1.0         1   2       1          64
# 85    86           1626     0          2.7         0   3       0          20
# 241  242           1169     1          1.4         1   7       1          51
# 215  216            951     1          2.4         0   1       1          24
#
# ...

# %%
# reset_index()  >>>> Use to reset the data

# %%
data.reset_index(drop = True, inplace = True)

# %%
data
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
# Apply function on data

# %%
data['clock_speed'] = data['clock_speed'].apply(lambda x:x/100)

# %%
data
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1        0.018         1  14       0           5
# 1       2            841     1        0.005         1   4       1          61
# 2       3           1807     1        0.028         0   1       0          27
# 3       4           1546     0        0.005         1  18       1          25
# 4       5           1434     0        0.014         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1        0.019         0   0       1          54
# 996   997            609     0        0.018         1   0       0          13
# 997   998           1185     0        0.014         0   1       1           8
# 998   999           1533     1        0.005         1   0       0          50
# 999  1000           1270     1        0.005         0   4       1          35
#
# ...
