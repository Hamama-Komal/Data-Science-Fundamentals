# %%
import pandas as pd

# %%
data = pd.read_csv('test_dataset.csv')

# %%
data
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
# Changing Data

# %%
price_list = ['Rs 120','Rs 14.9','Rs 99.9','Rs 125','Rs 178.0','Rs 1900' ]

# %%
# Edit the data

# %%
# data['Column Name'].str.lower()      >>>> To Covert to lower case

# %%
# Cleaning of data

# %%
# fillna() >> use to fill the NaN values      (if inpalce is true, it change the original data)

# %%
# dropna() >> use to remove the data where value is NaN   (if inpalce is true, it change the original data)

# %%
# To Add data

# %%
# .fillna(value, inplace = True)          >>>> Given value is added in the selected column where value is NaN

# %%
# to add new column

# %%
# test_column = [1,... 1000]

# %%
# data['new_coulmn'] = test_column   >> Now add the new column in our data. Make sure that item length must be equal

# %%
new_data = data.head(5)

# %%
new_data
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test_column = [1,2,3,4,5]

# %%
# new_data['new_column'] = test_column

# %%
# Add a single value in column

# %%
# new_data['new_column'] = 3

# %%
# Column (axis = 1) & Row (axis = 0)

# %%
data = data.drop('battery_power', axis = 1, inplace = True)           # >> Delete the given column

# %%
data
